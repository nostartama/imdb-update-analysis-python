# %% [markdown]
# ## IMDB Database

# %% [markdown]
# ### Dataset

# %%
url = 'https://raw.githubusercontent.com/scalabretta/GroupProject--IMDB/master/Dataset/IMDB-database-update.csv'
imdb_updates = pd.read_csv(url, encoding='latin1')
imdb_updaetes = imdb_updates.set_index('movie_ID')
# Out:
#                                         movie_title  duration  color  \
# movie_ID
# 1                                            Avatar       178      1
# 2          Pirates of the Caribbean: At World's End       169      1
# 3                             The Dark Knight Rises       164      1
# 4                                      Spider-Man 3       156      1
# 5                Batman v Superman: Dawn of Justice       183      1
# 6                                  Superman Returns       169      1
# 7                                      Man of Steel       143      1
# 8         The Hobbit: The Battle of the Five Armies       164      1
# 9                            The Amazing Spider-Man       153      1
# 10                                       Robin Hood       156      1
# 11                                        King Kong       201      1
# 12                                          Titanic       194      1
# ...

# %% [markdown]
# ### Melihat Gambaran Dataset

# %%
imdb_updates.head()
# Out:
#    movie_ID                               movie_title  duration  color  \
# 0         1                                    Avatar       178      1
# 1         2  Pirates of the Caribbean: At World's End       169      1
# 2         3                     The Dark Knight Rises       164      1
# 3         4                              Spider-Man 3       156      1
# 4         5        Batman v Superman: Dawn of Justice       183      1
#
#    title_year country language content_rating  budget_USD  gross_USD  \
# 0        2009     USA  English          PG-13   237000000  760505847
# 1        2007     USA  English          PG-13   300000000  309404152
# 2        2012     USA  English          PG-13   250000000  448130642
# 3        2007     USA  English          PG-13   258000000  336530303
# 4        2016     USA  English          PG-13   250000000  330249062
#
#        ...       actor_3_facebook?  actor_3_facebook_likes  \
# 0      ...                       1                     855
# ...

# %%
imdb_updates.describe()
# Out:
#           movie_ID     duration        color   title_year    budget_USD  \
# count  3781.000000  3781.000000  3781.000000  3781.000000  3.781000e+03
# mean   1891.000000   109.950278     0.967204  2003.081989  4.572770e+07
# std    1091.625012    22.299267     0.178125     9.837954  2.252895e+08
# min       1.000000    37.000000     0.000000  1927.000000  2.180000e+02
# 25%     946.000000    95.000000     1.000000  1999.000000  1.000000e+07
# 50%    1891.000000   106.000000     1.000000  2005.000000  2.500000e+07
# 75%    2836.000000   120.000000     1.000000  2010.000000  5.000000e+07
# max    3781.000000   325.000000     1.000000  2016.000000  1.221550e+10
#
#           gross_USD       net_USD   profitable  director_facebook?  \
# count  3.781000e+03  3.781000e+03  3781.000000         3781.000000
# mean   5.182002e+07  6.092318e+06     0.531870            0.828352
# std    7.003776e+07  2.291199e+08     0.499049            0.377124
# ...

# %% [markdown]
# ### Melihat dimensi dataset

# %%
imdb_updates.shape
# Out:
# (3781, 36)

# %% [markdown]
# ### Melihat variabel kolom

# %%
imdb_updates.dtypes
# Out:
# movie_ID                       int64
# movie_title                   object
# duration                       int64
# color                          int64
# title_year                     int64
# country                       object
# language                      object
# content_rating                object
# budget_USD                     int64
# gross_USD                      int64
# net_USD                        int64
# profitable                     int64
# director_name                 object
# director_top20?               object
# director_facebook?             int64
# director_facebook_likes        int64
# actor_1_name                  object
# actor_top20?                   int64
# actor_1_facebook?              int64
# actor_1_facebook_likes         int64
# actor_2_name                  object
# actor_top20?.1                 int64
# actor_2_facebook?              int64
# actor_2_facebook_likes         int64
# actor_3_name                  object
# ...

# %% [markdown]
# ### 1. How many rows and columns reflected on dataset file IMDB-database-update.csv?

# %%
imdb2 = imdb_updates[['movie_title','net_USD','title_year']]
imdb2['title_year']=2013
imdb2 = imdb2.sort_values(by='net_USD', ascending=False)
imdb2.head()
# Out:
# C:\Users\tiorah064123\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                              movie_title    net_USD  title_year
# 0                                 Avatar  523505847        2013
# 14                        Jurassic World  502177271        2013
# 11                               Titanic  458672302        2013
# 2294  Star Wars: Episode IV - A New Hope  449935665        2013
# 1112          E.T. the Extra-Terrestrial  424449459        2013

# %% [markdown]
# ### 2. What are the top 3 movies with highest nett profit in 2013?

# %%
imdb2 = imdb_updates[['movie_title','net_USD','title_year']]
imdb2 = imdb2.loc[imdb2['title_year'] == 2013]
imdb2_sort= imdb2.sort_values(by='net_USD', ascending=False)
imdb2_sort.iloc[0:3]
# Out:
#                           movie_title    net_USD  title_year
# 1614  The Hunger Games: Catching Fire  294645577        2013
# 236                   Despicable Me 2  292049635        2013
# 57                             Frozen  250736600        2013

# %% [markdown]
# ### 3. What are the top 3 movies with highest gross profit in 2009?

# %%
imdb3 = imdb_updates[['movie_title','gross_USD','title_year']]
imdb3 = imdb3.loc[imdb3['title_year'] == 2009]
imdb3 = imdb3.sort_values(by='gross_USD', ascending=False)
imdb3.iloc[:3]
# Out:
#                                  movie_title  gross_USD  title_year
# 0                                     Avatar  760505847        2009
# 19       Transformers: Revenge of the Fallen  402076689        2009
# 3094  Harry Potter and the Half-Blood Prince  301956980        2009

# %% [markdown]
# ### 4. How many non-english movies are in the dataset?

# %%
imdb4 = imdb_updates
len(imdb4.loc[imdb4['language'] != 'English'])
# Out:
# 153

# %% [markdown]
# ### 5. What are top 3 languages in the dataset aside English (based on number of movies)?

# %%
imdb5 = imdb_updates
imdb5 = imdb5.loc[imdb5['language'] != 'English']
imdb5["language"].value_counts().nlargest(3)
# Out:
# French      33
# Spanish     23
# Mandarin    14
# Name: language, dtype: int64

# %% [markdown]
# ### 6. What are the top 3 countries with the highest nett profit in all dataset times?

# %%
imdb6 = imdb_updates[['movie_title','net_USD','country']]
imdb6_sum = imdb6.groupby('country').sum().sort_values('net_USD', ascending=False)
imdb6_sum.head(3)
# Out:
#                net_USD
# country
# USA        52003933174
# UK          1531614524
# Australia    252571616

# %% [markdown]
# ### 7. What are the average budget of all movies in dataset in 2013?

# %%
imdb7 = imdb_updates[['title_year','budget_USD']]
imdb7 = imdb7.loc[imdb7['title_year'] == 2013]
imdb7['budget_USD'].mean()
# Out:
# 51069610.77439024

# %% [markdown]
# ### 8. What are the average budget of all movies in dataset in 2014?

# %%
imdb8 = imdb_updates[['title_year','budget_USD']]
imdb8 = imdb8.loc[imdb8['title_year'] == 2014]
imdb8['budget_USD'].mean()
# Out:
# 49919006.62251656

# %% [markdown]
# ### 9. Which one is higher, average budget of all movies in dataset in 2014 or 2013?

# %%
imdb9 = imdb_updates[['title_year','budget_USD']]
imdb9_2013 = imdb9['title_year'] == 2013 
imdb9_2014 = imdb9['title_year'] == 2014
imdb_uye= df[imdb9_2013 | imdb9_2014]
imdb_avg = imdb_uye.groupby('title_year').mean()
imdb_avg = imdb_avg['budget_USD']
print(imdb_avg)
# Out:
# title_year
# 2013    5.106961e+07
# 2014    4.991901e+07
# Name: budget_USD, dtype: float64

# %% [markdown]
# ### 10. What movie that resulted highest nett profit of all dataset times? How much did the movie make?

# %%
imdb10 = imdb_updates
imdb10 = imdb10.sort_values(by='net_USD', ascending=False)
imdb10[['movie_title','net_USD']].head(1)
# Out:
#   movie_title    net_USD
# 0      Avatar  523505847
